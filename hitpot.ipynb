# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
similarity_matrix = np.loadtxt('/data/home/liuzw/NR/pdb/structural/horizontal_matrices.txt')
sns.heatmap(similarity_matrix, cmap='coolwarm', annot=False, fmt=".2f")
plt.title('Candidate Similarity Matrix')
plt.xlabel('Protein Index')
plt.ylabel('Protein Index')
plt.show()
